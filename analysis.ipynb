# %%
print("My analysis notebook")
# Out:
# My analysis notebook

# %%
file = open('cars.csv')

lines = file.readlines()

file.close()

for line in lines[:5]:
    print(line.strip())

for line in lines[1:6]:
    row = line.strip().split(',')
    print(row)

for line in lines[1:]:
    row = line.strip().split(',')

    mpg = float(row[7])

    if mpg > 30:
        print(row[0], mpg)

# %%
import pandas as pd 
your_data = pd.read_csv("cars.csv")
your_data.head()
